# %%
"""
import tensorflow as tf
gpu_fraction = 0.1
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=gpu_fraction)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
"""

# %%
"""
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
"""

# %%
"""
import tensorflow as tf
tf.__version__sess = tf.Session(config=tf.ConfigProto(log_device_placement=True)) 
print
"""

# %%
#tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
#tf.device
# Out:
# <function tensorflow.python.framework.ops.device(device_name_or_function)>

# %%
"""
import tensorflow as tf
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
"""

# %%
#!pip install tensorflow_probability
# Out:
# Collecting tensorflow_probability
#   Using cached https://files.pythonhosted.org/packages/a1/ca/6f213618b5f7d0bf6139e6ec928d412a5ca14e4776adfd41a59c74a34021/tensorflow_probability-0.5.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /home/samin/environments/py36_baseline/lib/python3.6/site-packages (from tensorflow_probability) (1.11.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/samin/environments/py36_baseline/lib/python3.6/site-packages (from tensorflow_probability) (1.15.4)
# Installing collected packages: tensorflow-probability
# Successfully installed tensorflow-probability-0.5.0

# %%
import tensorflow as tf
import keras
#import mdn
from keras.layers import Bidirectional, Concatenate, Permute, Dot, Input, LSTM, Multiply
from keras.layers import RepeatVector, Dense, Activation, Lambda,MaxPooling1D ,Dropout,BatchNormalization
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.models import load_model, Model
import keras.backend as K
import numpy as np

from keras.callbacks import ModelCheckpoint
#from keras.preprocessing.text import Tokenizer
#from at_nmt_utils import *
import matplotlib.pyplot as plt

# %%
#%matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import sys 

sys.path.insert(0,'..')
from utils import plot_stroke

# %%
strokes = np.load('strokes.npy',encoding='bytes')

# %%
with open('sentences.txt') as f:
    texts = f.readlines()

# %%
chars='ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz .#'  # for other char in texts


# unique contains all the unique characters in the file
unique = sorted(set(chars))

# creating a mapping from unique characters to indices
char2idx = {u:i for i, u in enumerate(unique)}
idx2char = {i:u for i, u in enumerate(unique)}

num_char = len(char2idx)

# %%
########## gives the best representation so far
stroke_len = 300
char_len = int(stroke_len/25)
char_len
# Out:
# 12

# %%
def check_char (char2idx,val):
    result = []
    if char2idx.get(val)!=None:
        result = char2idx[val]
    elif char2idx.get(val)==None :
        result = char2idx['#']
    return result

def str2num(texts):
    input_text = []
    for f in range(len(texts)):
        inps = texts[f]   
        data = list(map( lambda val: check_char (char2idx,val),inps ))
        input_text.append(data)
        #np.concatenate((a, b), axis=0)
    return np.vstack(input_text)

def pad_texts(text, char_len):  
    pads = char_len - len(text)
    for i in range(int(pads)):
        text = text+str(' ')
    return text

def tranc_text(texts, char_len):
    for i in range (len(texts)):
        if len(texts[i]) > char_len:
            texts[i] = texts[i][0:int(char_len)]

        elif len(texts[i]) < char_len:
            texts[i] = pad_texts(texts[i],char_len)
    return texts

# %%
texts = tranc_text(texts, char_len)
n_texts = str2num(texts)
C = np.array(list(map(lambda x: to_categorical(x, num_classes=len(char2idx)), n_texts)))

# %%
Tx = stroke_len
Ty = stroke_len

def pad_stroke(stroke,Ty):
    _npads = Ty - stroke.shape[0] 
    padded_stroke = np.vstack ([ stroke,np.zeros((_npads,3)) ])
    #padded_strokes.shape
    return padded_stroke

def tranc_stroke(stroke, Ty):
    if stroke.shape[0] >= Ty:
        stroke = stroke[:Ty,]
    elif stroke.shape[0] < Ty:
        stroke = pad_stroke(stroke,Ty)
    #return input_stroke,output_stroke
    return stroke

new_strokes = np.array(list(map(lambda x: tranc_stroke(x, Ty+1), strokes)))
Xoh = new_strokes[:,:Ty,:]
Yoh = new_strokes[:,1:Ty+1,:]

# %%
def softmax(x, axis=1):
    ndim = K.ndim(x)
    if ndim == 2:
        return K.softmax(x)
    elif ndim > 2:
        e = K.exp(x - K.max(x, axis=axis, keepdims=True))
        s = K.sum(e, axis=axis, keepdims=True)
        return e / s

# %%
# Defined shared layers as global variables
repeator = RepeatVector(Tx)
concatenator = Concatenate(axis=-1)
densor1 = Dense(100, activation = "tanh")
densor2 = Dense(1, activation = "relu")
pooling = MaxPooling1D(pool_size=25, strides=25, padding="same")
activator = Activation(softmax, name='attention_weights') # We are using a custom softmax(axis = 1) loaded in this notebook
dotor = Dot(axes = 1)

# %%
def one_step_attention(a, s_prev,C):
    s_prev = repeator(s_prev)
    concat = concatenator ([s_prev,a]) # (?,500,600)
    e =  densor1(concat) 
    e = pooling(e)          # (?,20,100)
    e2 = BatchNormalization()(e)
    energies = densor2(e2)   # (?,20,1)
    alphas = activator(energies)   # (?,20,1)
    #context = dotor([alphas,a])
    context = dotor([alphas,C])  # context = (?,1,55); alpha = (?,20,1) , alpha = (?,20,55)
    return context

# %%
n_a = 128  #bi-directional in total ends up having 300 variables
n_s = 256
output_dim = 3
n_mix = 10
input_feat_size = Xoh.shape[2]   #3
output_feat_size = Yoh.shape[2]   #3

#post_activation_LSTM_cell = LSTM(n_s, return_state = True)
#output_layer = Dense(len(machine_vocab), activation=softmax)
#mix_model = mdn.MDN(output_dim, n_mix)
#output_layer = Dense(3, activation = "sigmoid")

post_activation_LSTM_cell = LSTM(n_s,activation='tanh',recurrent_dropout=0.2,return_state = True)
out_densor1 = Dense(100, kernel_initializer='random_uniform', activation = "tanh")
out_densor2 = Dense(100, kernel_initializer='random_uniform' , activation = "tanh")
out_densor3 = Dense(3, kernel_initializer='random_uniform' , activation = "tanh")

# %%
def model(Tx, Ty, n_a, n_s, input_feat_size, output_feat_size, char_len, num_char):
    X = Input(shape=(Tx, input_feat_size))
    C = Input(shape=(char_len, num_char))   # one hot encoded vector
    s0 = Input(shape=(n_s,), name='s0')
    c0 = Input(shape=(n_s,), name='c0')
    s = s0
    c = c0
    

    outputs = []
    #a = Bidirectional(LSTM(n_a, return_sequences=True),input_shape=(Tx, input_feat_size))(X)
    a = Bidirectional(LSTM(n_a,activation='tanh',recurrent_dropout=0.2,return_sequences=True),input_shape=(Tx, input_feat_size))(X)
    for t in range(Ty):
        context = one_step_attention(a, s, C)
        s, _, c = post_activation_LSTM_cell(context,initial_state= [s, c])
        #out = mix_model(s)
        #out = output_layer(s)
        output_l1 =  out_densor1(s) 
        output_l1 = BatchNormalization()(output_l1)
        
        output_l2 = out_densor2(output_l1) 
        output_l2 = BatchNormalization()(output_l2)
        
        out = out_densor3(output_l2)
        outputs.append(out)    
    model = Model(inputs=[X,C,s0,c0], outputs=outputs)
    return model

# %%
#char_len = total number of characters in input text C
# num_char = number of possible characters
model = model(Tx, Ty, n_a, n_s, input_feat_size, input_feat_size,char_len, num_char)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# s0 (InputLayer)                 (None, 256)          0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 300, 3)       0
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 300, 256)     0           s0[0][0]
#                                                                  lstm_3[0][0]
#                                                                  lstm_3[1][0]
#                                                                  lstm_3[2][0]
#                                                                  lstm_3[3][0]
#                                                                  lstm_3[4][0]
#                                                                  lstm_3[5][0]
#                                                                  lstm_3[6][0]
#                                                                  lstm_3[7][0]
#                                                                  lstm_3[8][0]
#                                                                  lstm_3[9][0]
#                                                                  lstm_3[10][0]
#                                                                  lstm_3[11][0]
#                                                                  lstm_3[12][0]
#                                                                  lstm_3[13][0]
#                                                                  lstm_3[14][0]
#                                                                  lstm_3[15][0]
#                                                                  lstm_3[16][0]
#                                                                  lstm_3[17][0]
#                                                                  lstm_3[18][0]
#                                                                  lstm_3[19][0]
#                                                                  lstm_3[20][0]
#                                                                  lstm_3[21][0]
#                                                                  lstm_3[22][0]
#                                                                  lstm_3[23][0]
#                                                                  lstm_3[24][0]
#                                                                  lstm_3[25][0]
#                                                                  lstm_3[26][0]
#                                                                  lstm_3[27][0]
#                                                                  lstm_3[28][0]
#                                                                  lstm_3[29][0]
#                                                                  lstm_3[30][0]
#                                                                  lstm_3[31][0]
#                                                                  lstm_3[32][0]
#                                                                  lstm_3[33][0]
#                                                                  lstm_3[34][0]
#                                                                  lstm_3[35][0]
#                                                                  lstm_3[36][0]
#                                                                  lstm_3[37][0]
#                                                                  lstm_3[38][0]
#                                                                  lstm_3[39][0]
#                                                                  lstm_3[40][0]
#                                                                  lstm_3[41][0]
#                                                                  lstm_3[42][0]
#                                                                  lstm_3[43][0]
#                                                                  lstm_3[44][0]
#                                                                  lstm_3[45][0]
#                                                                  lstm_3[46][0]
#                                                                  lstm_3[47][0]
#                                                                  lstm_3[48][0]
#                                                                  lstm_3[49][0]
#                                                                  lstm_3[50][0]
#                                                                  lstm_3[51][0]
#                                                                  lstm_3[52][0]
#                                                                  lstm_3[53][0]
#                                                                  lstm_3[54][0]
#                                                                  lstm_3[55][0]
#                                                                  lstm_3[56][0]
#                                                                  lstm_3[57][0]
#                                                                  lstm_3[58][0]
#                                                                  lstm_3[59][0]
#                                                                  lstm_3[60][0]
#                                                                  lstm_3[61][0]
#                                                                  lstm_3[62][0]
#                                                                  lstm_3[63][0]
#                                                                  lstm_3[64][0]
#                                                                  lstm_3[65][0]
#                                                                  lstm_3[66][0]
#                                                                  lstm_3[67][0]
#                                                                  lstm_3[68][0]
#                                                                  lstm_3[69][0]
#                                                                  lstm_3[70][0]
#                                                                  lstm_3[71][0]
#                                                                  lstm_3[72][0]
#                                                                  lstm_3[73][0]
#                                                                  lstm_3[74][0]
#                                                                  lstm_3[75][0]
#                                                                  lstm_3[76][0]
#                                                                  lstm_3[77][0]
#                                                                  lstm_3[78][0]
#                                                                  lstm_3[79][0]
#                                                                  lstm_3[80][0]
#                                                                  lstm_3[81][0]
#                                                                  lstm_3[82][0]
#                                                                  lstm_3[83][0]
#                                                                  lstm_3[84][0]
#                                                                  lstm_3[85][0]
#                                                                  lstm_3[86][0]
#                                                                  lstm_3[87][0]
#                                                                  lstm_3[88][0]
#                                                                  lstm_3[89][0]
#                                                                  lstm_3[90][0]
#                                                                  lstm_3[91][0]
#                                                                  lstm_3[92][0]
#                                                                  lstm_3[93][0]
#                                                                  lstm_3[94][0]
#                                                                  lstm_3[95][0]
#                                                                  lstm_3[96][0]
#                                                                  lstm_3[97][0]
#                                                                  lstm_3[98][0]
#                                                                  lstm_3[99][0]
#                                                                  lstm_3[100][0]
#                                                                  lstm_3[101][0]
#                                                                  lstm_3[102][0]
#                                                                  lstm_3[103][0]
#                                                                  lstm_3[104][0]
#                                                                  lstm_3[105][0]
#                                                                  lstm_3[106][0]
#                                                                  lstm_3[107][0]
#                                                                  lstm_3[108][0]
#                                                                  lstm_3[109][0]
#                                                                  lstm_3[110][0]
#                                                                  lstm_3[111][0]
#                                                                  lstm_3[112][0]
#                                                                  lstm_3[113][0]
#                                                                  lstm_3[114][0]
#                                                                  lstm_3[115][0]
#                                                                  lstm_3[116][0]
#                                                                  lstm_3[117][0]
#                                                                  lstm_3[118][0]
#                                                                  lstm_3[119][0]
#                                                                  lstm_3[120][0]
#                                                                  lstm_3[121][0]
#                                                                  lstm_3[122][0]
#                                                                  lstm_3[123][0]
#                                                                  lstm_3[124][0]
#                                                                  lstm_3[125][0]
#                                                                  lstm_3[126][0]
#                                                                  lstm_3[127][0]
#                                                                  lstm_3[128][0]
#                                                                  lstm_3[129][0]
#                                                                  lstm_3[130][0]
#                                                                  lstm_3[131][0]
#                                                                  lstm_3[132][0]
#                                                                  lstm_3[133][0]
#                                                                  lstm_3[134][0]
#                                                                  lstm_3[135][0]
#                                                                  lstm_3[136][0]
#                                                                  lstm_3[137][0]
#                                                                  lstm_3[138][0]
#                                                                  lstm_3[139][0]
#                                                                  lstm_3[140][0]
#                                                                  lstm_3[141][0]
#                                                                  lstm_3[142][0]
#                                                                  lstm_3[143][0]
#                                                                  lstm_3[144][0]
#                                                                  lstm_3[145][0]
#                                                                  lstm_3[146][0]
#                                                                  lstm_3[147][0]
#                                                                  lstm_3[148][0]
#                                                                  lstm_3[149][0]
#                                                                  lstm_3[150][0]
#                                                                  lstm_3[151][0]
#                                                                  lstm_3[152][0]
#                                                                  lstm_3[153][0]
#                                                                  lstm_3[154][0]
#                                                                  lstm_3[155][0]
#                                                                  lstm_3[156][0]
#                                                                  lstm_3[157][0]
#                                                                  lstm_3[158][0]
#                                                                  lstm_3[159][0]
#                                                                  lstm_3[160][0]
#                                                                  lstm_3[161][0]
#                                                                  lstm_3[162][0]
#                                                                  lstm_3[163][0]
#                                                                  lstm_3[164][0]
#                                                                  lstm_3[165][0]
#                                                                  lstm_3[166][0]
#                                                                  lstm_3[167][0]
#                                                                  lstm_3[168][0]
#                                                                  lstm_3[169][0]
#                                                                  lstm_3[170][0]
#                                                                  lstm_3[171][0]
#                                                                  lstm_3[172][0]
#                                                                  lstm_3[173][0]
#                                                                  lstm_3[174][0]
#                                                                  lstm_3[175][0]
#                                                                  lstm_3[176][0]
#                                                                  lstm_3[177][0]
#                                                                  lstm_3[178][0]
#                                                                  lstm_3[179][0]
#                                                                  lstm_3[180][0]
#                                                                  lstm_3[181][0]
#                                                                  lstm_3[182][0]
#                                                                  lstm_3[183][0]
#                                                                  lstm_3[184][0]
#                                                                  lstm_3[185][0]
#                                                                  lstm_3[186][0]
#                                                                  lstm_3[187][0]
#                                                                  lstm_3[188][0]
#                                                                  lstm_3[189][0]
#                                                                  lstm_3[190][0]
#                                                                  lstm_3[191][0]
#                                                                  lstm_3[192][0]
#                                                                  lstm_3[193][0]
#                                                                  lstm_3[194][0]
#                                                                  lstm_3[195][0]
#                                                                  lstm_3[196][0]
#                                                                  lstm_3[197][0]
#                                                                  lstm_3[198][0]
#                                                                  lstm_3[199][0]
#                                                                  lstm_3[200][0]
#                                                                  lstm_3[201][0]
#                                                                  lstm_3[202][0]
#                                                                  lstm_3[203][0]
#                                                                  lstm_3[204][0]
#                                                                  lstm_3[205][0]
#                                                                  lstm_3[206][0]
#                                                                  lstm_3[207][0]
#                                                                  lstm_3[208][0]
#                                                                  lstm_3[209][0]
#                                                                  lstm_3[210][0]
#                                                                  lstm_3[211][0]
#                                                                  lstm_3[212][0]
#                                                                  lstm_3[213][0]
#                                                                  lstm_3[214][0]
#                                                                  lstm_3[215][0]
#                                                                  lstm_3[216][0]
#                                                                  lstm_3[217][0]
#                                                                  lstm_3[218][0]
#                                                                  lstm_3[219][0]
#                                                                  lstm_3[220][0]
#                                                                  lstm_3[221][0]
#                                                                  lstm_3[222][0]
#                                                                  lstm_3[223][0]
#                                                                  lstm_3[224][0]
#                                                                  lstm_3[225][0]
#                                                                  lstm_3[226][0]
#                                                                  lstm_3[227][0]
#                                                                  lstm_3[228][0]
#                                                                  lstm_3[229][0]
#                                                                  lstm_3[230][0]
#                                                                  lstm_3[231][0]
#                                                                  lstm_3[232][0]
#                                                                  lstm_3[233][0]
#                                                                  lstm_3[234][0]
#                                                                  lstm_3[235][0]
#                                                                  lstm_3[236][0]
#                                                                  lstm_3[237][0]
#                                                                  lstm_3[238][0]
#                                                                  lstm_3[239][0]
#                                                                  lstm_3[240][0]
#                                                                  lstm_3[241][0]
#                                                                  lstm_3[242][0]
#                                                                  lstm_3[243][0]
#                                                                  lstm_3[244][0]
#                                                                  lstm_3[245][0]
#                                                                  lstm_3[246][0]
#                                                                  lstm_3[247][0]
#                                                                  lstm_3[248][0]
#                                                                  lstm_3[249][0]
#                                                                  lstm_3[250][0]
#                                                                  lstm_3[251][0]
#                                                                  lstm_3[252][0]
#                                                                  lstm_3[253][0]
#                                                                  lstm_3[254][0]
#                                                                  lstm_3[255][0]
#                                                                  lstm_3[256][0]
#                                                                  lstm_3[257][0]
#                                                                  lstm_3[258][0]
#                                                                  lstm_3[259][0]
#                                                                  lstm_3[260][0]
#                                                                  lstm_3[261][0]
#                                                                  lstm_3[262][0]
#                                                                  lstm_3[263][0]
#                                                                  lstm_3[264][0]
#                                                                  lstm_3[265][0]
#                                                                  lstm_3[266][0]
#                                                                  lstm_3[267][0]
#                                                                  lstm_3[268][0]
#                                                                  lstm_3[269][0]
#                                                                  lstm_3[270][0]
#                                                                  lstm_3[271][0]
#                                                                  lstm_3[272][0]
#                                                                  lstm_3[273][0]
#                                                                  lstm_3[274][0]
#                                                                  lstm_3[275][0]
#                                                                  lstm_3[276][0]
#                                                                  lstm_3[277][0]
#                                                                  lstm_3[278][0]
#                                                                  lstm_3[279][0]
#                                                                  lstm_3[280][0]
#                                                                  lstm_3[281][0]
#                                                                  lstm_3[282][0]
#                                                                  lstm_3[283][0]
#                                                                  lstm_3[284][0]
#                                                                  lstm_3[285][0]
#                                                                  lstm_3[286][0]
#                                                                  lstm_3[287][0]
#                                                                  lstm_3[288][0]
#                                                                  lstm_3[289][0]
#                                                                  lstm_3[290][0]
#                                                                  lstm_3[291][0]
#                                                                  lstm_3[292][0]
#                                                                  lstm_3[293][0]
#                                                                  lstm_3[294][0]
#                                                                  lstm_3[295][0]
#                                                                  lstm_3[296][0]
#                                                                  lstm_3[297][0]
#                                                                  lstm_3[298][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 300, 256)     135168      input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 300, 512)     0           repeat_vector_1[2][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[3][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[4][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[5][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[6][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[7][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[8][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[9][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[10][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[11][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[12][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[13][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[14][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[15][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[16][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[17][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[18][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[19][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[20][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[21][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[22][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[23][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[24][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[25][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[26][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[27][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[28][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[29][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[30][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[31][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[32][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[33][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[34][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[35][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[36][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[37][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[38][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[39][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[40][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[41][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[42][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[43][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[44][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[45][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[46][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[47][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[48][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[49][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[50][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[51][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[52][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[53][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[54][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[55][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[56][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[57][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[58][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[59][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[60][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[61][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[62][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[63][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[64][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[65][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[66][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[67][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[68][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[69][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[70][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[71][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[72][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[73][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[74][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[75][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[76][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[77][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[78][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[79][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[80][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[81][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[82][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[83][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[84][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[85][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[86][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[87][0]
#                                                                  bidirectional_3[0][0]
#                                                                  repeat_vector_1[88][0]
#                                                                  bidirectional_3[0][0]
# ...
#                                                                  batch_normalization_429[0][0]
#                                                                  batch_normalization_432[0][0]
#                                                                  batch_normalization_435[0][0]
#                                                                  batch_normalization_438[0][0]
#                                                                  batch_normalization_441[0][0]
#                                                                  batch_normalization_444[0][0]
#                                                                  batch_normalization_447[0][0]
#                                                                  batch_normalization_450[0][0]
#                                                                  batch_normalization_453[0][0]
#                                                                  batch_normalization_456[0][0]
#                                                                  batch_normalization_459[0][0]
#                                                                  batch_normalization_462[0][0]
#                                                                  batch_normalization_465[0][0]
#                                                                  batch_normalization_468[0][0]
#                                                                  batch_normalization_471[0][0]
#                                                                  batch_normalization_474[0][0]
#                                                                  batch_normalization_477[0][0]
#                                                                  batch_normalization_480[0][0]
#                                                                  batch_normalization_483[0][0]
#                                                                  batch_normalization_486[0][0]
#                                                                  batch_normalization_489[0][0]
#                                                                  batch_normalization_492[0][0]
#                                                                  batch_normalization_495[0][0]
#                                                                  batch_normalization_498[0][0]
#                                                                  batch_normalization_501[0][0]
#                                                                  batch_normalization_504[0][0]
#                                                                  batch_normalization_507[0][0]
#                                                                  batch_normalization_510[0][0]
#                                                                  batch_normalization_513[0][0]
#                                                                  batch_normalization_516[0][0]
#                                                                  batch_normalization_519[0][0]
#                                                                  batch_normalization_522[0][0]
#                                                                  batch_normalization_525[0][0]
#                                                                  batch_normalization_528[0][0]
#                                                                  batch_normalization_531[0][0]
#                                                                  batch_normalization_534[0][0]
#                                                                  batch_normalization_537[0][0]
#                                                                  batch_normalization_540[0][0]
#                                                                  batch_normalization_543[0][0]
#                                                                  batch_normalization_546[0][0]
#                                                                  batch_normalization_549[0][0]
#                                                                  batch_normalization_552[0][0]
#                                                                  batch_normalization_555[0][0]
#                                                                  batch_normalization_558[0][0]
#                                                                  batch_normalization_561[0][0]
#                                                                  batch_normalization_564[0][0]
#                                                                  batch_normalization_567[0][0]
#                                                                  batch_normalization_570[0][0]
#                                                                  batch_normalization_573[0][0]
#                                                                  batch_normalization_576[0][0]
#                                                                  batch_normalization_579[0][0]
#                                                                  batch_normalization_582[0][0]
#                                                                  batch_normalization_585[0][0]
#                                                                  batch_normalization_588[0][0]
#                                                                  batch_normalization_591[0][0]
#                                                                  batch_normalization_594[0][0]
#                                                                  batch_normalization_597[0][0]
#                                                                  batch_normalization_600[0][0]
#                                                                  batch_normalization_603[0][0]
#                                                                  batch_normalization_606[0][0]
#                                                                  batch_normalization_609[0][0]
#                                                                  batch_normalization_612[0][0]
#                                                                  batch_normalization_615[0][0]
#                                                                  batch_normalization_618[0][0]
#                                                                  batch_normalization_621[0][0]
#                                                                  batch_normalization_624[0][0]
#                                                                  batch_normalization_627[0][0]
#                                                                  batch_normalization_630[0][0]
#                                                                  batch_normalization_633[0][0]
#                                                                  batch_normalization_636[0][0]
#                                                                  batch_normalization_639[0][0]
#                                                                  batch_normalization_642[0][0]
#                                                                  batch_normalization_645[0][0]
#                                                                  batch_normalization_648[0][0]
#                                                                  batch_normalization_651[0][0]
#                                                                  batch_normalization_654[0][0]
#                                                                  batch_normalization_657[0][0]
#                                                                  batch_normalization_660[0][0]
#                                                                  batch_normalization_663[0][0]
#                                                                  batch_normalization_666[0][0]
#                                                                  batch_normalization_669[0][0]
#                                                                  batch_normalization_672[0][0]
#                                                                  batch_normalization_675[0][0]
#                                                                  batch_normalization_678[0][0]
#                                                                  batch_normalization_681[0][0]
#                                                                  batch_normalization_684[0][0]
#                                                                  batch_normalization_687[0][0]
#                                                                  batch_normalization_690[0][0]
#                                                                  batch_normalization_693[0][0]
#                                                                  batch_normalization_696[0][0]
#                                                                  batch_normalization_699[0][0]
#                                                                  batch_normalization_702[0][0]
#                                                                  batch_normalization_705[0][0]
#                                                                  batch_normalization_708[0][0]
#                                                                  batch_normalization_711[0][0]
#                                                                  batch_normalization_714[0][0]
#                                                                  batch_normalization_717[0][0]
#                                                                  batch_normalization_720[0][0]
#                                                                  batch_normalization_723[0][0]
#                                                                  batch_normalization_726[0][0]
#                                                                  batch_normalization_729[0][0]
#                                                                  batch_normalization_732[0][0]
#                                                                  batch_normalization_735[0][0]
#                                                                  batch_normalization_738[0][0]
#                                                                  batch_normalization_741[0][0]
#                                                                  batch_normalization_744[0][0]
#                                                                  batch_normalization_747[0][0]
#                                                                  batch_normalization_750[0][0]
#                                                                  batch_normalization_753[0][0]
#                                                                  batch_normalization_756[0][0]
#                                                                  batch_normalization_759[0][0]
#                                                                  batch_normalization_762[0][0]
#                                                                  batch_normalization_765[0][0]
#                                                                  batch_normalization_768[0][0]
#                                                                  batch_normalization_771[0][0]
#                                                                  batch_normalization_774[0][0]
#                                                                  batch_normalization_777[0][0]
#                                                                  batch_normalization_780[0][0]
#                                                                  batch_normalization_783[0][0]
#                                                                  batch_normalization_786[0][0]
#                                                                  batch_normalization_789[0][0]
#                                                                  batch_normalization_792[0][0]
#                                                                  batch_normalization_795[0][0]
#                                                                  batch_normalization_798[0][0]
#                                                                  batch_normalization_801[0][0]
#                                                                  batch_normalization_804[0][0]
#                                                                  batch_normalization_807[0][0]
#                                                                  batch_normalization_810[0][0]
#                                                                  batch_normalization_813[0][0]
#                                                                  batch_normalization_816[0][0]
#                                                                  batch_normalization_819[0][0]
#                                                                  batch_normalization_822[0][0]
#                                                                  batch_normalization_825[0][0]
#                                                                  batch_normalization_828[0][0]
#                                                                  batch_normalization_831[0][0]
#                                                                  batch_normalization_834[0][0]
#                                                                  batch_normalization_837[0][0]
#                                                                  batch_normalization_840[0][0]
#                                                                  batch_normalization_843[0][0]
#                                                                  batch_normalization_846[0][0]
#                                                                  batch_normalization_849[0][0]
#                                                                  batch_normalization_852[0][0]
#                                                                  batch_normalization_855[0][0]
#                                                                  batch_normalization_858[0][0]
#                                                                  batch_normalization_861[0][0]
#                                                                  batch_normalization_864[0][0]
#                                                                  batch_normalization_867[0][0]
#                                                                  batch_normalization_870[0][0]
#                                                                  batch_normalization_873[0][0]
#                                                                  batch_normalization_876[0][0]
#                                                                  batch_normalization_879[0][0]
#                                                                  batch_normalization_882[0][0]
#                                                                  batch_normalization_885[0][0]
#                                                                  batch_normalization_888[0][0]
#                                                                  batch_normalization_891[0][0]
#                                                                  batch_normalization_894[0][0]
#                                                                  batch_normalization_897[0][0]
#                                                                  batch_normalization_900[0][0]
# ==================================================================================================
# Total params: 902,160
# Trainable params: 722,160
# Non-trainable params: 180,000
# __________________________________________________________________________________________________

# %%
#opt = Adam(lr=0.005, decay=0.01, beta_1=0.9, beta_2=0.999)
#model.compile(optimizer=opt,
#              loss='categorical_crossentropy',
#              metrics=['accuracy'])

#model.compile(loss=mdn.get_mixture_loss_func(output_dim, n_mix), optimizer=keras.optimizers.Adam())

# %%
opt = Adam(lr=0.005, decay=0.01, beta_1=0.9, beta_2=0.999,clipvalue=100)
model.compile(optimizer=opt,
              loss='mean_squared_error',
              metrics=['accuracy'])

# %%
m = Xoh.shape[0]  # no of examples we have for training
s0 = np.zeros((m, n_s))
c0 = np.zeros((m, n_s))
outputs = list(Yoh.swapaxes(0,1))

# %%
filepath="AttentionModel-NN-writing-gen-weights.{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model.fit([Xoh,C, s0, c0], outputs, validation_split=0.33, epochs=20, batch_size=32,callbacks=callbacks_list)
print('training completed')
model.save('AttentionModel-NN-writing-gen-weights_batch32_epoch20.h5')  # creates a HDF5 file 'my_model.h5'
# Out:
# Train on 4019 samples, validate on 1981 samples
# Epoch 1/20
